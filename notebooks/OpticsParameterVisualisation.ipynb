# %%
import madx.optics_parameters as mop
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import time
import importlib
import data.bunch_configuration as buc
import visualization.optics_parameter_visualisation as opv
sns.set_style("whitegrid")
# Out:
# Welcome to JupyROOT 6.16/00

# %%
path_to_configuration = "/home/rafalmucha/Pobrane/optic/s/"

# %%
# Parameters of bunch
x_mean = 0.0
sigma_x = 0
theta_x_mean = 0
sigma_theta_x = 0
y_mean = 0.0
sigma_y = 0
theta_y_mean = 0.00
sigma_theta_y = 0
pt_mean = -0.075
sigma_pt = 0.075

number_of_x_values = 1
number_of_theta_x_values = 1
number_of_y_values = 1
number_of_theta_y_values = 1
number_of_pt_values = 100

# %%
bunch_configuration = buc.BunchConfiguration.from_sigma(x_mean, sigma_x, number_of_x_values,
                                                        theta_x_mean, sigma_theta_x, number_of_theta_x_values,
                                                        y_mean, sigma_y, number_of_y_values,
                                                        theta_y_mean, sigma_theta_y, number_of_theta_y_values,
                                                        pt_mean, sigma_pt, number_of_pt_values)

# %%
opv.plot_optical_function_of_madx(path_to_configuration, bunch_configuration, mop.compute_v_x, "pt", "v x", "madx")

# %%
opv.plot_optical_function_of_madx(path_to_configuration, bunch_configuration, mop.compute_v_y, "pt", "v y", "madx")

# %%
opv.plot_optical_function_of_madx(path_to_configuration, bunch_configuration, mop.compute_l_x, "pt", "l x", "madx")

# %%
opv.plot_optical_function_of_madx(path_to_configuration, bunch_configuration, mop.compute_l_y, "pt", "l y", "madx")

# %%
opv.plot_optical_function_of_madx(path_to_configuration, bunch_configuration, mop.compute_d_x, "pt", "D x", "madx")

# %%
opv.plot_optical_function_of_madx(path_to_configuration, bunch_configuration, mop.compute_d_y, "pt", "D y", "madx")
