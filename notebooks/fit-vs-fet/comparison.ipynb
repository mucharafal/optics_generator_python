# %%
import uproot
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
samples = uproot.open("config/samples_beam_1_ip_150.root")['transport_samples']
samples.keys()
# Out:
# [b'x_in',
#  b'theta_x_in',
#  b'y_in',
#  b'theta_y_in',
#  b'ksi_in',
#  b's_in',
#  b'def_x_out',
#  b'def_theta_x_out',
#  b'def_y_out',
#  b'def_theta_y_out',
#  b'def_ksi_out',
#  b'def_s_out',
#  b'def_valid_out',
#  b'mqxb.b2r5_x_out',
#  b'mqxb.b2r5_theta_x_out',
#  b'mqxb.b2r5_y_out',
#  b'mqxb.b2r5_theta_y_out',
#  b'mqxb.b2r5_ksi_out',
#  b'mqxb.b2r5_s_out',
#  b'mqxb.b2r5_valid_out',
#  b'mcbxh.3r5_x_out',
#  b'mcbxh.3r5_theta_x_out',
#  b'mcbxh.3r5_y_out',
#  b'mcbxh.3r5_theta_y_out',
#  b'mcbxh.3r5_ksi_out',
#  b'mcbxh.3r5_s_out',
#  b'mcbxh.3r5_valid_out',
#  b'tanc.4r5_x_out',
#  b'tanc.4r5_theta_x_out',
#  b'tanc.4r5_y_out',
#  b'tanc.4r5_theta_y_out',
#  b'tanc.4r5_ksi_out',
#  b'tanc.4r5_s_out',
#  b'tanc.4r5_valid_out',
#  b'mcbxh.2r5_x_out',
#  b'mcbxh.2r5_theta_x_out',
#  b'mcbxh.2r5_y_out',
#  b'mcbxh.2r5_theta_y_out',
#  b'mcbxh.2r5_ksi_out',
#  b'mcbxh.2r5_s_out',
#  b'mcbxh.2r5_valid_out',
#  b'mqxa.3r5_x_out',
#  b'mqxa.3r5_theta_x_out',
# ...

# %%
df = samples.pandas.df([key for key in samples.allkeys() if len(samples[key].array()) > 0])
df
# Out:
#            x_in  theta_x_in      y_in  theta_y_in    ksi_in      def_x_out  \
# entry
# 0     -0.001288   -0.000037 -0.000349   -0.000221 -0.045675  6.899297e-310
# 1      0.000507   -0.001273  0.002428    0.000097 -0.286991  6.899297e-310
# 2     -0.000653    0.001253 -0.000099    0.000512 -0.313715  6.899297e-310
# 3      0.002480    0.000872 -0.001283   -0.001161 -0.306341  6.899297e-310
# 4     -0.003326    0.000269 -0.000338    0.000361 -0.164837  6.899297e-310
# 5     -0.001288   -0.000037 -0.000349   -0.000221 -0.045675  6.899297e-310
# 6      0.002372    0.000308  0.002623   -0.001283 -0.176565  6.899297e-310
# 7      0.002372    0.000308  0.002623   -0.001283 -0.176565  6.899297e-310
# 8      0.002372    0.000308  0.002623   -0.001283 -0.176565  6.899297e-310
# 9      0.002372    0.000308  0.002623   -0.001283 -0.176565  6.899297e-310
# 10     0.002372    0.000308  0.002623   -0.001283 -0.176565  6.899297e-310
# ...

# %%
plt.plot(df['x_in'], df['theta_x_in'], 'ro')

# %%
plt.plot(df['x_in'], df['y_in'], 'ro')

# %%
plt.plot(df['x_in'], df['def_x_out'], 'ro')

# %%
# now w/o matplotlib, only with pandas builtins
df.plot(kind = 'scatter', x = 'x_in', y = 'y_in')

# %%
# now lets try adding some fancy stuff
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
df.plot(kind = 'scatter', x = 'x_in', y = 'y_in', ax=ax)
ax.set_title('Scatter plot of y_in vs x_in')
ax.set_xlabel('x_in')
ax.set_ylabel('y_in')
# Out:
# Text(0, 0.5, 'y_in')

# %%
# bar plots, but theres no categorical data, so lets try histograms
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
df['x_in'].plot.hist(ax=ax)
ax.set_title('Histogram of x_in')
ax.set_xlabel('x_in')
ax.set_ylabel('Number of elements')
# Out:
# Text(0, 0.5, 'Number of elements')

# %%
# would try box plots but again, no categorical data
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
df[['x_in', 'y_in']].boxplot(ax = ax)
ax.set_title('Boxplot of x_in and y_in without grouping bc no categorical data')
ax.set_xlabel('x_in')
ax.set_ylabel('y_in')
# Out:
# Text(0, 0.5, 'y_in')

# %%
# now some seaborn
sns.set_style('whitegrid')
sns.kdeplot(df['x_in'])

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
sns.set_style('whitegrid')
sns.kdeplot(df['x_in'], ax = ax)
ax.set_title('KDE plot of x_in')
ax.set_xlabel('x_in')
ax.set_ylabel('density')
# Out:
# Text(0, 0.5, 'density')

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
sns.set_style('whitegrid')
sns.kdeplot(df[['x_in', 'y_in']], ax = ax, cmap='Blues_d')
ax.set_title('KDE plot of x_in and y_in')
ax.set_xlabel('x_in')
ax.set_ylabel('y_in')
# Out:
# /home/kbak/.local/lib/python3.7/site-packages/seaborn/distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)
# Text(0, 0.5, 'y_in')

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
sns.set_style('whitegrid')
sns.violinplot(x = 'x_in', y = 'ksi_in', data = df, ax = ax)
ax.set_title('Violin plot of x_in and ksi_in')
ax.set_xlabel('x_in')
ax.set_ylabel('ksi_in')
# not really working, should get two nice violins :(
# Out:
# Text(0, 0.5, 'ksi_in')

# %%
sns.lmplot(x = 'x_in', y = 'ksi_in', data = df, palette='Set2', fit_reg=True)

# %%
sns.pairplot(df[['x_in', 'theta_x_in', 'y_in', 'theta_y_in']], palette='Set2', diag_kind='kde', size=2).map_upper(sns.kdeplot, cmap='Blues_d')
# Out:
# /home/kbak/.local/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
# facets plots (groupped by operation, divide data and plot on mulitple axies)
g = sns.FacetGrid(df, col='x_in', row='')
g.map(sns.regplot, 'y_in', 'ksi_in', fit_reg=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-6c1cab602ccb> in <module>
# ...

# %%
g = sns.FacetGrid(df, col='x_in', row='theta_y_in')
g.map(sns.regplot, 'y_in', 'ksi_in', fit_reg=False)

# %%
samples1 = uproot.open("config/samples_beam_1_ip_150.root")['transport_samples']
samples2 = uproot.open("config/samples_beam_1_ip_150.root")['transport_samples']
df1 = samples1.pandas.df([key for key in samples.allkeys() if len(samples[key].array()) > 0])
df2 = samples2.pandas.df([key for key in samples.allkeys() if len(samples[key].array()) > 0])

# %%
df1['x_in']
# Out:
# entry
# 0       -0.001288
# 1        0.000507
# 2       -0.000653
# 3        0.002480
# 4       -0.003326
# 5       -0.001288
# 6        0.002372
# 7        0.002372
# 8        0.002372
# 9        0.002372
# 10       0.002372
# 11       0.000507
# 12       0.000507
# 13       0.000507
# 14       0.000507
# 15       0.000507
# 16       0.000507
# 17       0.000507
# 18       0.000507
# 19      -0.000833
# 20      -0.000833
# 21      -0.000833
# 22      -0.000833
# 23      -0.000653
# 24      -0.000653
# 25      -0.000653
# 26      -0.000653
# 27       0.000974
# 28       0.000974
# 29       0.000974
#            ...
# 10287   -0.000584
# 10288   -0.000584
# 10289   -0.000584
# 10290   -0.000584
# 10291   -0.000584
# 10292   -0.000584
# 10293   -0.000584
# 10294   -0.000584
# 10295   -0.000584
# 10296   -0.000584
# 10297   -0.000584
# 10298   -0.000584
# 10299   -0.000584
# 10300   -0.000584
# 10301   -0.000584
# 10302   -0.000584
# 10303   -0.000584
# 10304   -0.000584
# ...

# %%
Index= ['aaa', 'bbb', 'ccc', 'ddd', 'eee']
Cols = ['A', 'B', 'C', 'D']
df5 = pd.DataFrame(abs(np.random.randn(5, 4)), index=Index, columns=Cols)

sns.heatmap(df5, annot=True)
