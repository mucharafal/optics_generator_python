# %%
import parameters_generator.optics_parameter_grid_generator_angle as pg
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import time
import importlib
importlib.reload(pg)
# Out:
# <module 'parameters_generator.optics_parameter_grid_generator_angle' from '/home/rafalmucha/Pobrane/optic/optics_generator_python/src/parameters_generator/optics_parameter_grid_generator_angle.py'>

# %%
path_to_configuration = "/home/rafalmucha/Pobrane/optic/s/"

# %%
x_mean = 0.0000
theta_x_mean = 0.00000
y_mean = 0.000
theta_y_mean = 0.000
pt_mean = 0.001

# %%
begin = time.time()
resolution = 4
grid = pg.compute_d_x(x_mean, 0.00001, 10, 
               theta_x_mean, 0.0000001, 100,
               0, 0, 1,
               0, 0, 1,
               0, 0, 1,
               pt_mean, 0.001, 10,
               path_to_configuration)
end = time.time()
print(end - begin)
grid.shape
# Out:
# (6, 10000)
# (10000, 10)
# (6, 10000)
# (10000, 10)
# End, parameter calc
# (10000,)
# 4.974148273468018
# (10000, 6)

# %%
x = grid.T[0]
y = grid.T[1]
frame = pd.DataFrame(data={"x_out [m]": x, "theta_x": y})
ax = sns.scatterplot(x="x_out [m]", y="theta_x",
                data=frame)
import numpy as np
x_min = np.min(x)
x_max = np.max(x)
y_min = np.min(y)
y_max = np.max(y)

delta_x = x_max - x_min
delta_y = y_max - y_min

ax.set_xlim(x_min - 0.25 * delta_x, x_max + 0.25 * delta_x)
# Out:
# (-1.5000000000000002e-05, 1.5000000000000002e-05)

# %%
x = grid.T[0]
y = grid.T[5]
frame = pd.DataFrame(data={"x_in [m]": x, "dispersion_from_x [m]": y})
ax = sns.scatterplot(x="x_in [m]", y="dispersion_from_x [m]",
                data=frame)

x_min = np.min(x)
x_max = np.max(x)
y_min = np.min(y)
y_max = np.max(y)

delta_x = x_max - x_min
delta_y = y_max - y_min

ax.set_xlim(x_min - 0.25 * delta_x, x_max + 0.25 * delta_x)
# Out:
# (-1.5000000000000002e-05, 1.5000000000000002e-05)

# %%
sns.jointplot(x, y, kind="kde", height=5, space=0).set_axis_labels(xlabel="x in [m]", ylabel="dispersion_from_x [m]").fig.suptitle("Dispersion in depend from input x")
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-7-ceee3c9e7221> in <module>
# ----> 1 sns.jointplot(x, y, kind="kde", height=5, space=0).set_axis_labels(xlabel="x in [m]", ylabel="dispersion_from_x [m]").fig.suptitle("Dispersion in depend from input x")
#
# ~/.local/lib/python3.7/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2312         joint_kws.setdefault("shade", True)
#    2313         joint_kws.setdefault("cmap", cmap)
# -> 2314         grid.plot_joint(kdeplot, **joint_kws)
#    2315
#    2316         marginal_kws.setdefault("shade", True)
#
# ~/.local/lib/python3.7/site-packages/seaborn/axisgrid.py in plot_joint(self, func, **kwargs)
#    1782         """
#    1783         plt.sca(self.ax_joint)
# ...

# %%
x_name = "theta_x"
y_name = "dispersion_from_x [m]"

x = grid.T[1]
y = grid.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame)

# %%
x_name = "y [m]"
y_name = "dispersion_from_x [m]"

x = grid.T[2]
y = grid.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame)

# %%
x_name = "theta_y [m]"
y_name = "dispersion_from_x [m]"

x = grid.T[3]
y = grid.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame)

# %%
x_name = "ksi"
y_name = "dispersion_from_x [m]"

x = grid.T[4]
y = grid.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame)

# %%
begin = time.time()
grid2 = pg.compute_d_x(x_mean, 0.001, 10, 
               theta_x_mean, 0.0001, 100,
               y_mean, 0, 1,
               theta_y_mean, 0, 1,
                0, 0, 1,
               pt_mean, 0, 1,
               path_to_configuration)
end = time.time()
print(end - begin)
grid2.shape
# Out:
# (6, 1000)
# (1000, 10)
# (6, 1000)
# (1000, 10)
# End, parameter calc
# (1000,)
# 2.7599384784698486
# (1000, 6)

# %%
f, axes = plt.subplots(2, 3)

fig = plt.gcf()
fig.set_size_inches(20,20)

x = grid2.T[0]
y = grid2.T[5]
frame = pd.DataFrame(data={"x_in [m]": x, "dispersion_from_x [m]": y})
sns.scatterplot(x="x_in [m]", y="dispersion_from_x [m]",
                data=frame, ax=axes[0][0])

x_name = "theta_x"
y_name = "dispersion_from_x [m]"

x = grid2.T[1]
y = grid2.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][1])

x_name = "y [m]"

x = grid2.T[2]
y = grid2.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][2])

x_name = "theta_y [m]"

x = grid2.T[3]
y = grid2.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[1][0])

x_name = "ksi"

x = grid2.T[4]
y = grid2.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[1][1])

# %%
x = grid2.T[1]
y = grid2.T[5]
sns.jointplot(x, y, kind="kde", height=5, space=0).set_axis_labels(xlabel="theta_x_in", ylabel="dispersion_from_x [m]").fig.suptitle("Dispersion in depend from input theta x")
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-17-82c8a6cef6bc> in <module>
#       1 x = grid2.T[1]
#       2 y = grid2.T[5]
# ----> 3 sns.jointplot(x, y, kind="kde", height=5, space=0).set_axis_labels(xlabel="theta_x_in", ylabel="dispersion_from_x [m]").fig.suptitle("Dispersion in depend from input theta x")
#
# ~/.local/lib/python3.7/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2312         joint_kws.setdefault("shade", True)
#    2313         joint_kws.setdefault("cmap", cmap)
# -> 2314         grid.plot_joint(kdeplot, **joint_kws)
#    2315
#    2316         marginal_kws.setdefault("shade", True)
#
# ~/.local/lib/python3.7/site-packages/seaborn/axisgrid.py in plot_joint(self, func, **kwargs)
#    1782         """
# ...

# %%
begin = time.time()
grid = pg.compute_l_x(x_mean, 0.01, 40, 
               theta_x_mean, 0.001, 20,
               y_mean, 0.0, 1,
               theta_y_mean, 0.0, 1,
               0, 0, 1,
               pt_mean, 0.001, 30,
               path_to_configuration)
end = time.time()
print(end - begin)
# Out:
# (6, 24000)
# (24000, 10)
# (6, 24000)
# (24000, 10)
# 9.900283813476562

# %%
f, axes = plt.subplots(2, 3)

fig = plt.gcf()
fig.set_size_inches(20,20)

x_name = "x [m]"
y_name = "L_from_x [m]"

x = grid.T[0]
y = grid.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][0])

x_name = "theta_x"

x = grid.T[1]
y = grid.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][1])

x_name = "y [m]"

x = grid.T[2]
y = grid.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][2])

x_name = "theta_y [m]"

x = grid.T[3]
y = grid.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[1][0])

x_name = "ksi"

x = grid.T[4]
y = grid.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[1][1])

# %%
begin = time.time()
grid4 = pg.compute_v_x(x_mean, 0.01, 100, 
               theta_x_mean, 0.001, 20,
               y_mean, 0.0, 1,
               theta_y_mean, 0.0, 1,
                0, 0, 1,
               pt_mean, 0.01, 10,
               path_to_configuration)
end = time.time()
print(end - begin)
grid4.shape
# Out:
# (6, 20000)
# (20000, 10)
# (6, 20000)
# (20000, 10)
# 8.304684400558472
# (9320, 6)

# %%
f, axes = plt.subplots(2, 3)

fig = plt.gcf()
fig.set_size_inches(20,20)

x_name = "x [m]"
y_name = "v_from_x"

x = grid4.T[0]
y = grid4.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][0])

x_name = "theta_x"

x = grid4.T[1]
y = grid4.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][1])

x_name = "y [m]"

x = grid4.T[2]
y = grid4.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][2])

x_name = "theta_y [m]"

x = grid4.T[3]
y = grid4.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[1][0])

x_name = "ksi"

x = grid4.T[4]
y = grid4.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[1][1])

# %%
grid4.shape
# Out:
# (9320, 6)

# %%
begin = time.time()
grid5 = pg.compute_v_y(x_mean, 0.0, 1, 
               theta_x_mean, 0., 1,
               y_mean, 0.01, 100,
               theta_y_mean, 0.001, 20,
                0, 0, 1,
               pt_mean, 0, 1,
               path_to_configuration)
end = time.time()
print(end - begin)
# Out:
# (6, 2000)
# (2000, 10)
# (6, 2000)
# (2000, 10)
# 3.118457078933716

# %%
f, axes = plt.subplots(2, 3)

fig = plt.gcf()
fig.set_size_inches(20,20)

x_name = "x [m]"
y_name = "v_from_y"

x = grid5.T[0]
y = grid5.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][0])

x_name = "theta_x"

x = grid5.T[1]
y = grid5.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][1])

x_name = "y [m]"

x = grid5.T[2]
y = grid5.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][2])

x_name = "theta_y [m]"

x = grid5.T[3]
y = grid5.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[1][0])

x_name = "ksi"

x = grid5.T[4]
y = grid5.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[1][1])

# %%
begin = time.time()
grid6 = pg.compute_l_y(x_mean, 0.0, 1, 
               theta_x_mean, 0, 1,
               y_mean, 0.01, 20,
               theta_y_mean, 0.001, 20,
                0, 0, 1,
               pt_mean, 0.01, 40,
               path_to_configuration)
end = time.time()
print(end - begin)
# Out:
# (6, 16000)
# (16000, 10)
# (6, 16000)
# (16000, 10)
# 6.731866836547852

# %%
f, axes = plt.subplots(2, 3)

fig = plt.gcf()
fig.set_size_inches(20,20)

x_name = "x [m]"
y_name = "L_from_y [m]"

x = grid6.T[0]
y = grid6.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][0])

x_name = "theta_x"

x = grid6.T[1]
y = grid6.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][1])

x_name = "y [m]"

x = grid6.T[2]
y = grid6.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][2])

x_name = "theta_y [m]"

x = grid6.T[3]
y = grid6.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[1][0])

x_name = "ksi"

x = grid6.T[4]
y = grid6.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[1][1])

# %%
begin = time.time()
grid7 = pg.compute_d_y(x_mean, 0.0, 1, 
               theta_x_mean, 0., 1,
               y_mean, 0.01, 20,
               theta_y_mean, 0.001, 200,
                       0, 0, 1,
               pt_mean, 0., 1,
               path_to_configuration)
end = time.time()
print(end - begin)
# Out:
# (6, 4000)
# (4000, 10)
# (6, 4000)
# (4000, 10)
# 3.3391010761260986

# %%
f, axes = plt.subplots(2, 3)

fig = plt.gcf()
fig.set_size_inches(20,20)

x_name = "x [m]"
y_name = "D_from_y [m]"

x = grid7.T[0]
y = grid7.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][0])

x_name = "theta_x"

x = grid7.T[1]
y = grid7.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][1])

x_name = "y [m]"

x = grid7.T[2]
y = grid7.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[0][2])

x_name = "theta_y [m]"

x = grid7.T[3]
y = grid7.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[1][0])

x_name = "ksi"

x = grid7.T[4]
y = grid7.T[5]
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame, ax=axes[1][1])

# %%
x = grid7.T[2]
y = grid7.T[3]
x_name = "y [m]"
y_name = "theta y"
frame = pd.DataFrame(data={x_name: x, y_name: y})
sns.scatterplot(x=x_name, y=y_name,
                data=frame)
